# %%
class myLR:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self,x_train,y_train):
        num =0
        den =0
        x_train_mean = x_train.mean()
        y_train_mean = y_train.mean()
        for i in range(x_train.shape[0]):
            num += ((x_train[i] -x_train_mean)*(y_train[i]-y_train_mean))
            den += ((x_train[i] -x_train_mean)*(x_train[i] -x_train_mean))
        self.m = num/den
        self.b = y_train_mean - (self.m*x_train_mean)
        print(self.m)
        print(self.b)
    def predict(self,x_test):
        print(x_test)
        return self.m*x_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student_performance_linear.csv")

# %%
df.head()
# Out:
#    study_hours  exam_score
# 0          1.2          42
# 1          8.5          95
# 2          5.4          78
# 3          3.1          55
# 4          9.8          99

# %%
#values bcz I want to extract numpy array
x = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state=2)

# %%
x_train.shape
# Out:
# (511,)

# %%
lr = myLR()

# %%
lr.fit(x_train,y_train)
# Out:
# 7.555145666532063
# 36.30808588919667

# %%
x_test[0]
# Out:
# np.float64(3.5)

# %%
lr.predict(x_test[0])
# Out:
# 3.5
# np.float64(62.75109572205889)
