# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student_performance_linear.csv")

# %%
df.head()
# Out:
#    study_hours  exam_score
# 0          1.2          42
# 1          8.5          95
# 2          5.4          78
# 3          3.1          55
# 4          9.8          99

# %%
plt.scatter(df["study_hours"],df["exam_score"])
plt.xlabel("study_hours")
plt.ylabel("exam_score")
# Out:
# Text(0, 0.5, 'exam_score')

# %%
a =df["study_hours"].values
b = df.iloc[:,0:1]
print(type(a))
print(type(a))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
x = df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      study_hours
# 0            1.2
# 1            8.5
# 2            5.4
# 3            3.1
# 4            9.8
# ..           ...
# 634          5.7
# 635          0.3
# 636          8.7
# 637          3.4
# 638          7.9
#
# [639 rows x 1 columns]

# %%
y
# Out:
# 0       42
# 1       95
# 2       78
# 3       55
# 4       99
#       ...
# 634     84
# 635     37
# 636    100
# 637     67
# 638     99
# Name: exam_score, Length: 639, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      study_hours
# 617          3.5
# 572          1.1
# 1            8.5
# 68           3.4
# 37           1.6
# ..           ...
# 222          1.4
# 399          5.1
# 389          5.4
# 109          4.7
# 462          4.2
#
# [128 rows x 1 columns]

# %%
y_test
# Out:
# 617    68
# 572    44
# 1      95
# 68     62
# 37     45
#        ..
# 222    43
# 399    77
# 389    80
# 109    71
# 462    71
# Name: exam_score, Length: 128, dtype: int64

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))
# Out:
# C:\Users\ENVY\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([100.52682405])

# %%
plt.scatter(df["study_hours"],df["exam_score"])
plt.plot(x_test,lr.predict(x_test),color='red')
# plt.plot(x_train,lr.predict(x_train),color='green')
plt.xlabel("study_hours")
plt.ylabel("exam_score")
# Out:
# Text(0, 0.5, 'exam_score')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y=mx+b
m
# Out:
# array([7.55514567])

# %%
b
# Out:
# np.float64(36.30808588919668)
